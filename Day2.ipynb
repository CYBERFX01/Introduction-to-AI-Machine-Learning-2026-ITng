# %% [markdown]
# Example 1: Import Pandas

# %%
import pandas as pd

print("Pandas imported successfully")
# Out:
# Pandas imported successfully

# %% [markdown]
# Example 2: Create DataFrame Manually

# %%
import pandas as pd

data = {
    "Name": ["Abubakar", "Waziri", "Ibrahim"],
    "Age": [24, 27, 22]
}

df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age
# 0  Abubakar   24
# 1    Waziri   27
# 2   Ibrahim   22

# %% [markdown]
# Example 3: Load CSV File

# %%
import pandas as pd

df = pd.read_csv("goldprice.csv")  # replace with your file

# %% [markdown]
# Example 4: View First Rows

# %%
print(df.head())
# Out:
#        Date        Open        High         Low       Close  Volume
# 0  30-08-00  273.899994  273.899994  273.899994  273.899994       0
# 1  31-08-00  274.799988  278.299988  274.799988  278.299988       0
# 2  01-09-00  277.000000  277.000000  277.000000  277.000000       0
# 3  05-09-00  275.799988  275.799988  275.799988  275.799988       2
# 4  06-09-00  274.200012  274.200012  274.200012  274.200012       0

# %% [markdown]
# Example 5: View Last Rows

# %%
print(df.tail())
# Out:
#           Date         Open         High          Low        Close  Volume
# 6394  25-02-26  5166.000000  5206.399902  5166.000000  5206.399902    1772
# 6395  26-02-26  5177.200195  5199.200195  5143.899902  5176.500000    1520
# 6396  27-02-26  5186.700195  5280.000000  5176.700195  5230.500000     354
# 6397  02-03-26  5346.600098  5405.000000  5266.299805  5294.399902     354
# 6398  03-03-26  5335.700195  5394.200195  5334.899902  5377.299805   21189

# %% [markdown]
# Example 6: Data Inspection (info)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6399 entries, 0 to 6398
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    6399 non-null   object
#  1   Open    6399 non-null   float64
#  2   High    6399 non-null   float64
#  3   Low     6399 non-null   float64
#  4   Close   6399 non-null   float64
#  5   Volume  6399 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 300.1+ KB
# None

# %% [markdown]
# Example 7: Summary Statistics

# %%
print(df.describe())
# Out:
#               Open         High          Low        Close         Volume
# count  6399.000000  6399.000000  6399.000000  6399.000000    6399.000000
# mean   1274.892437  1281.728724  1267.908032  1274.961009    4282.543522
# std     782.868133   788.800733   777.090788   783.122438   24051.637361
# min     255.000000   256.100006   255.000000   255.100006       0.000000
# 25%     651.000000   653.649994   649.149994   651.699982      23.000000
# 50%    1251.599976  1256.199951  1244.800049  1251.099976     117.000000
# 75%    1694.700012  1706.099976  1683.250000  1695.649964     450.500000
# max    5415.700195  5586.200195  5334.899902  5377.299805  386334.000000

# %% [markdown]
# Example 8: Select Columns

# %%
print(df["Open"])
# Out:
# 0        273.899994
# 1        274.799988
# 2        277.000000
# 3        275.799988
# 4        274.200012
#            ...
# 6394    5166.000000
# 6395    5177.200195
# 6396    5186.700195
# 6397    5346.600098
# 6398    5335.700195
# Name: Open, Length: 6399, dtype: float64

# %% [markdown]
# Example 9: Filter Data

# %%
filtered = df[df["Open"] > 2000 ]
print(filtered)
# Out:
#           Date         Open         High          Low        Close  Volume
# 4997  05-08-20  2024.000000  2050.199951  2011.000000  2031.099976    1422
# 4998  06-08-20  2045.500000  2063.000000  2040.000000  2051.500000     294
# 4999  07-08-20  2040.099976  2055.000000  2009.599976  2010.099976     808
# 5000  10-08-20  2026.400024  2043.800049  2017.500000  2024.400024     233
# 5001  11-08-20  2012.400024  2016.000000  1904.000000  1932.599976     971
# ...        ...          ...          ...          ...          ...     ...
# 6394  25-02-26  5166.000000  5206.399902  5166.000000  5206.399902    1772
# 6395  26-02-26  5177.200195  5199.200195  5143.899902  5176.500000    1520
# 6396  27-02-26  5186.700195  5280.000000  5176.700195  5230.500000     354
# 6397  02-03-26  5346.600098  5405.000000  5266.299805  5294.399902     354
# 6398  03-03-26  5335.700195  5394.200195  5334.899902  5377.299805   21189
#
# [589 rows x 6 columns]

# %% [markdown]
# Example 10: Multiple Conditions

# %%
filtered = df[(df["Open"] > 2000) & (df["Low"] < 500)]
print(filtered)
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume]
# Index: []

# %% [markdown]
# =========================
#
# 📘 ASSIGNMENTS (4)
#
# =========================
#
# Assignment 1: Create DataFrame

# %%
# 1. Create a DataFrame with columns: Close, Volume, Date
# 2. Add at least 5 rows
# 3. Print the DataFrame

# %% [markdown]
# Assignment 2: Load & Inspect

# %%
# 1. Load a CSV file
# 2. Display first 5 rows
# 3. Display dataset info

# %% [markdown]
# Assignment 3: Filtering

# %%
# 1. Load dataset
# 2. Filter rows where Date > "2023-01-01"
# 3. Display result

# %% [markdown]
# Assignment 4: Column Selection + Stats

# %%
# 1. Select a numeric column (e.g., High)
# 2. Calculate mean, max, min
# 3. Print results
